# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt
import pandas as pd

torch.manual_seed(1)

# --- Frase ---
sentence = "Me gusta desayunar un kiwi".split()
vocab = {w: i for i, w in enumerate(sentence)}
indices = torch.tensor([vocab[w] for w in sentence])  # [seq_len]

# --- Embeddings ---
embedding_dim = 16
embed = nn.Embedding(len(vocab), embedding_dim)
x = embed(indices)  # [seq_len, embedding_dim]

print("Embeddings de cada palabra (x):\n", x.detach().numpy())

# --- Proyecciones Q, K, V ---
d_k = embedding_dim
W_q = nn.Linear(d_k, d_k, bias=False)
W_k = nn.Linear(d_k, d_k, bias=False)
W_v = nn.Linear(d_k, d_k, bias=False)

# Imprimir matrices de pesos
print("\nMatriz de pesos W_q:\n", W_q.weight.detach().numpy())
print("\nMatriz de pesos W_k:\n", W_k.weight.detach().numpy())
print("\nMatriz de pesos W_v:\n", W_v.weight.detach().numpy())

Q = W_q(x)
K = W_k(x)
V = W_v(x)

# --- Atención ---
scores = Q @ K.T  # Producto QK sin escalado
print("\nValores de la matriz QK (producto punto):\n", scores.detach().numpy())

# Escalado y softmax para obtener pesos de atención
scores_scaled = scores / (d_k ** 0.5)
attn_weights = F.softmax(scores_scaled, dim=-1)  # [seq_len, seq_len]
output = attn_weights @ V

# --- Mostrar valores como tabla ---
df = pd.DataFrame(attn_weights.detach().numpy(),
                  index=sentence, columns=sentence)

df_rounded = df.round(2)
print("\nPesos de atención (cada fila = query, cada columna = key):\n")
print(df_rounded)

# --- Visualización ---
plt.figure(figsize=(8, 6))
plt.imshow(attn_weights.detach().numpy(), cmap="Blues")
plt.colorbar()
plt.xticks(range(len(sentence)), sentence, rotation=90)
plt.yticks(range(len(sentence)), sentence)
plt.title("Mapa de atención")
plt.xlabel("Keys (a quién miro)")
plt.ylabel("Queries (quién mira)")
plt.show()
# Out:
# Embeddings de cada palabra (x):
#  [[-1.5255959  -0.7502318  -0.6539809  -1.6094848  -0.10016718 -0.6091889
#   -0.97977227 -1.6090963  -0.7121446   0.303722   -0.7773143  -0.25145525
#   -0.22227049  1.6871134   0.22842517  0.4676355 ]
#  [-0.6969724  -1.1607615   0.6995424   0.19908163  0.8656924   0.2444039
#   -0.66291136  0.80730826  1.1016806  -0.17593604 -2.2455578  -1.446458
#    0.06115528 -0.61774445 -0.79806983 -0.13162321]
#  [ 1.8793458  -0.07213178  0.1577706  -0.7734549   0.1990565   0.04570278
#    0.15295692 -0.4756788  -0.11101983  0.29273525 -0.15784515 -0.02878714
#    2.357111   -1.0373387   1.5747981  -0.6298472 ]
#  [-0.9273917   0.5451415   0.06628026 -0.43704012  0.7626006   0.44151092
#    1.1651385   2.0153918   0.13741246  0.9386447  -0.18600109 -0.6446393
#    1.5392458  -0.8695876  -3.3311536  -0.74787223]
#  [-0.02550246 -1.0233306  -0.59618515 -1.0055307  -0.2106063  -0.00754753
#    1.6734272   0.01034283 -0.70395666 -0.1852658  -0.9962351  -0.83125526
#   -0.13917547 -0.24304947  0.10075361 -0.09511644  0.17511639  0.17597929
#   -0.15944266 -0.14574313 -0.08873925  0.14643875]
#  [-0.00860575 -0.08931118  0.15487018  0.23708656  0.1848244  -0.19117638
#   -0.05192485 -0.04795304  0.21335068 -0.12930208 -0.14328256  0.00391144
#   -0.05807468  0.09462938  0.03038797 -0.1492633 ]
#  [ 0.1817872   0.15561965  0.0547466  -0.22628108  0.1174798   0.16611564
#    0.06960025 -0.09663582  0.0167667  -0.09603986  0.23536354  0.241404
#   -0.02913359 -0.16819936  0.14706314  0.12759554]
#  [ 0.13251907 -0.18811321  0.08477157 -0.10668758 -0.21973816 -0.17456922
#    0.10597664  0.09359467 -0.21941671  0.14176917  0.19156     0.18978202
#    0.14116067 -0.03924474  0.16751644  0.19571993]
#  [ 0.13032037 -0.17981258 -0.08725178  0.19805461  0.19059408  0.1595197
#   -0.10449007 -0.04951206 -0.18625239 -0.14247525  0.19190845 -0.20519471
#   -0.06178132  0.05306721 -0.15000308  0.05827516]
#  [-0.04018861  0.09998092 -0.1918459   0.03450102 -0.22793132  0.15509811
#    0.24284253 -0.08923057  0.03696755 -0.1288026  -0.15992129 -0.12661397
#   -0.11909923  0.04745549 -0.02865678  0.01752907]
#  [-0.19158277 -0.15706548 -0.21643013 -0.17968595  0.20935422  0.09288117
#   -0.23842475 -0.04172605  0.02006397  0.13355616  0.23186389  0.06036893
#    0.17610869 -0.08896104 -0.00816852 -0.1509166 ]
#  [ 0.0575926   0.23076391  0.1569947   0.24877033 -0.11264721 -0.03128061
#    0.05156836  0.20099315 -0.22981027 -0.12277776  0.03626513 -0.14450091
#    0.09339017 -0.01704374 -0.06478199  0.1340771 ]
#  [ 0.17866793  0.24317214  0.11321029 -0.00683683  0.20440167  0.19896069
#   -0.12529412  0.11387441  0.02929431 -0.10804302 -0.05953655 -0.05903319
#   -0.17494339 -0.07628894  0.08412683  0.18352938]
#  [ 0.01899007 -0.24210039  0.13240314 -0.07564622  0.22326279 -0.24157
#   -0.05849168  0.19388062  0.10815021 -0.12472704 -0.2164768  -0.00268513
#    0.09657776 -0.20754927 -0.20920086 -0.0031471 ]]
#
# Valores de la matriz QK (producto punto):
#  [[ 0.01892686  3.4042501  -0.42384753  1.7655467   0.8817318 ]
#  [ 0.55101496 -1.0730745   0.30521825 -2.1131086  -0.8768032 ]
#  [-0.6567392   0.3694405   0.73247796  1.8798249   0.7720061 ]
#  [-0.10155922 -2.1346433  -0.57727396 -4.0090914  -0.43994856]
#  [-0.19743857 -0.30171192 -0.08322555 -0.07996333 -0.5332217 ]]
#
# Pesos de atención (cada fila = query, cada columna = key):
#
#              Me  gusta  desayunar    un  kiwi
# Me         0.14   0.33       0.13  0.22  0.18
# gusta      0.26   0.17       0.25  0.13  0.18
# desayunar  0.14   0.18       0.20  0.27  0.20
# un         0.26   0.16       0.23  0.10  0.24
# kiwi       0.20   0.20       0.21  0.21  0.19
